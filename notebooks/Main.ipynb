# %% [markdown]
# Original implementation of graph-sc method
# (https://github.com/ciortanmadalina/graph-sc)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd /content/drive/MyDrive/graphsc_dir/graphsc
# Out:
# /content/drive/.shortcut-targets-by-id/1VHZIPFmOd_-Z3PGgavB9LVwCskoD0_-v/graphsc_dir/graphsc

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1VHZIPFmOd_-Z3PGgavB9LVwCskoD0_-v/graphsc_dir/graphsc

# %%
# !pip install dgl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dgl
#   Downloading dgl-0.9.1-cp38-cp38-manylinux1_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from dgl) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from dgl) (4.64.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.8/dist-packages (from dgl) (3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from dgl) (2.25.1)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from dgl) (1.7.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->dgl) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->dgl) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->dgl) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->dgl) (2.10)
# Installing collected packages: psutil, dgl
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed dgl-0.9.1 psutil-5.9.4

# %%
# !pip install scanpy
# Out:
# [autoreload of psutil._pslinux failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/psutil/_pslinux.py", line 87, in <module>
#     PAGESIZE = cext_posix.getpagesize()
# AttributeError: module 'psutil_posix' has no attribute 'getpagesize'
# ]
# [autoreload of psutil failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/psutil/__init__.py", line 241, in <module>
#     raise ImportError(msg)
# ImportError: version conflict: '/usr/local/lib/python3.8/dist-packages/psutil/_psutil_linux.cpython-38-x86_64-linux-gnu.so' C extension module was built for another version of psutil (5.4.8 instead of 5.9.4); you may try to 'pip uninstall psutil', manually remove /usr/local/lib/python3.8/dist-packages/psutil/_psutil_linux.cpython-38-x86_64-linux-gnu.so or clean the virtual env somehow, then reinstall
# ]
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scanpy
#   Downloading scanpy-1.9.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.1 MB/s eta 0:00:00
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.2.0)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.1.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy) (5.5.0)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 116.8 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.56.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy) (4.64.1)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scanpy) (21.3)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.7.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.21.6)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.11.2)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.0)
# Collecting anndata>=0.7.4
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.3.5)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 62.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (6.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scanpy) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy->scanpy) (1.15.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 69.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.41.0->scanpy) (3.11.0)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=d0d8cbb600034049fd66067769c82bed06d3e3b059c1286c6071e157a43b345e
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8046 sha256=e211de43a98efe29bd6ad664fc63a81107475edfbf9fa0a98076d709d5d3da79
#   Stored in directory: /root/.cache/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=8a30ce7e9d461531cb6cf6cb99e7b793d17ec27fd155f2b3e92d0c5c5bec9a8b
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, fonttools, contourpy, matplotlib, pynndescent, anndata, umap-learn, scanpy
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed anndata-0.8.0 contourpy-1.0.7 fonttools-4.38.0 matplotlib-3.6.3 pynndescent-0.5.8 scanpy-1.9.1 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3

# %%
# !pip install leidenalg
# Out:
# [autoreload of matplotlib.cbook failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: open_file_cm() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.colors failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/colors.py", line 1822, in <module>
#     scale.AsinhScale,
# AttributeError: module 'matplotlib.scale' has no attribute 'AsinhScale'
# ]
# [autoreload of matplotlib.rcsetup failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: validate_anylist() requires a code object with 2 free vars, not 3
# ]
# [autoreload of matplotlib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py", line 1472, in <module>
#     from matplotlib.cm import _colormaps as colormaps
# ImportError: cannot import name '_colormaps' from 'matplotlib.cm' (/usr/local/lib/python3.8/dist-packages/matplotlib/cm.py)
# ]
# [autoreload of matplotlib.path failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __deepcopy__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.transforms failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __copy__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.cm failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/cm.py", line 227, in <module>
#     globals().update(_colormaps)
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/cm.py", line 87, in __getitem__
#     return self._cmaps[item].copy()
# AttributeError: 'ListedColormap' object has no attribute 'copy'
# ]
# [autoreload of matplotlib.lines failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of matplotlib.collections failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of matplotlib.ticker failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: set_view_interval() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.font_manager failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: win32InstalledFonts() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.bezier failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: find_bezier_t_intersecting_with_closedpath() requires a code object with 4 free vars, not 0
# ]
# [autoreload of matplotlib.patches failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of matplotlib.dviread failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.mathtext failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_unicode_index() requires a code object with 0 free vars, not 10
# ]
# [autoreload of matplotlib.textpath failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_text_path() requires a code object with 3 free vars, not 0
# ]
# [autoreload of matplotlib.text failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_rotation() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.texmanager failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_font_config() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.blocking_input failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.contour failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/contour.py", line 1575, in <module>
#     _docstring.interpd.update(contour_doc="""
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/_docstring.py", line 53, in __missing__
#     raise KeyError(key)
# KeyError: 'cmap_doc'
# ]
# [autoreload of matplotlib.tight_layout failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: auto_adjust_subplotpars() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.gridspec failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_grid_positions() requires a code object with 0 free vars, not 10
# ]
# [autoreload of matplotlib.colorbar failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 10
# ]
# [autoreload of matplotlib.backend_tools failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: destroy() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.widgets failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.backend_bases failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.image failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# WARNING:matplotlib:Bad val 'round' on line #34
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #19
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-white.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'butt' on line #5
# 	"lines.solid_capstyle: butt
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/fivethirtyeight.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'path' on line #21
# 	"svg.fonttype: path
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/fivethirtyeight.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #19
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-darkgrid.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #19
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-whitegrid.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #15
# 	"lines.dash_joinstyle : round        # miter|round|bevel
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'butt' on line #16
# 	"lines.dash_capstyle : butt          # butt|round|projecting
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #17
# 	"lines.solid_joinstyle : round       # miter|round|bevel
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'projecting' on line #18
# 	"lines.solid_capstyle : projecting   # butt|round|projecting
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'full' on line #26
# 	"markers.fillstyle: full
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'cm' on line #158
# 	"mathtext.fontset : cm # Should be 'cm' (Computer Modern), 'stix',
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
#
# Bad key "mathtext.fallback" on line 160 in
# /usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.2.2/matplotlibrc.template
# or from the matplotlib source distribution
# WARNING:matplotlib:Bad val 'major' on line #178
# 	"axes.grid.which     : major
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'both' on line #179
# 	"axes.grid.axis      : both
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
#
# Bad key "axes.titley" on line 181 in
# /usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.2.2/matplotlibrc.template
# or from the matplotlib source distribution
# WARNING:matplotlib:Bad val 'round_numbers' on line #218
# 	"axes.autolimit_mode : round_numbers
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
#
# Bad key "date.converter" on line 235 in
# /usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.2.2/matplotlibrc.template
# or from the matplotlib source distribution
# WARNING:matplotlib:Bad val 'center' on line #256
# 	"xtick.alignment : center
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'center' on line #274
# 	"ytick.alignment      : center
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'upper right' on line #285
# 	"legend.loc           : upper right
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
#
# Bad key "figure.labelsize" on line 310 in
# /usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.2.2/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "figure.labelweight" on line 311 in
# /usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.2.2/matplotlibrc.template
# or from the matplotlib source distribution
# WARNING:matplotlib:Bad val 'upper' on line #336
# 	"image.origin : upper             # lower | upper
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val '1.5' on line #386
# 	"boxplot.whiskers: 1.5
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	name 'validate_nseq_float' is not defined
# WARNING:matplotlib:Bad val 'portrait' on line #431
# 	"savefig.orientation : portrait
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'letter' on line #434
# 	"ps.papersize      : letter   # auto, letter, legal, ledger, A0-A10, B0-B10
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'xelatex' on line #451
# 	"pgf.texsystem       : xelatex
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'path' on line #457
# 	"svg.fonttype : path            # How to handle SVG fonts:
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'ffmpeg' on line #478
# 	"animation.writer : ffmpeg         # MovieWriter 'backend' to use
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'png' on line #482
# 	"animation.frame_format: png       # Controls frame format used by temp files
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'none' on line #490
# 	"animation.html: none
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #19
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-dark.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'center_baseline' on line #6
# 	"ytick.alignment: center_baseline
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'cm' on line #13
# 	"mathtext.fontset : cm
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/bmh.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'round' on line #19
# 	"lines.solid_capstyle: round
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/seaborn-v0_8-ticks.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# WARNING:matplotlib:Bad val 'butt' on line #26
# 	"lines.solid_capstyle: butt
# "
# 	in file "/usr/local/lib/python3.8/dist-packages/matplotlib/mpl-data/stylelib/Solarize_Light2.mplstyle"
# 	'ValidateInStrings' object has no attribute '_deprecated_since'
# [autoreload of matplotlib.style.core failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: load_base_library() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.units failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: is_numlike() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.dates failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.offsetbox failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: set_figure() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.container failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.legend_handler failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.legend failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.mlab failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: stride_windows() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.quiver failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.streamplot failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_integrator() requires a code object with 0 free vars, not 2
# ]
# [autoreload of matplotlib.table failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of matplotlib.tri.tricontour failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/tri/tricontour.py", line 81, in <module>
#     _docstring.interpd.update(_tricontour_doc="""
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/_docstring.py", line 53, in __missing__
#     raise KeyError(key)
# KeyError: 'cmap_doc'
# ]
# [autoreload of matplotlib.tri.trifinder failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.tri.triinterpolate failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.tri.trirefine failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.scale failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of matplotlib.axis failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.axes._base failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.axes._secondary_axes failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: set_ticks() requires a code object with 4 free vars, not 0
# ]
# [autoreload of matplotlib.axes._axes failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py", line 47, in <module>
#     class Axes(_AxesBase):
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py", line 4407, in Axes
#     def scatter(self, x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/_docstring.py", line 80, in __call__
#     super().__call__(obj)
# KeyError: 'cmap_doc'
# ]
# [autoreload of matplotlib.projections.geo failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.projections.polar failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of mpl_toolkits.mplot3d.art3d failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of mpl_toolkits.mplot3d.axis3d failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: move_from_center() requires a code object with 0 free vars, not 2
# ]
# [autoreload of mpl_toolkits.mplot3d.axes3d failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py", line 45, in <module>
#     class Axes3D(Axes):
#   File "/usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py", line 58, in Axes3D
#     Axes._shared_axes["z"] = cbook.Grouper()
# AttributeError: type object 'Axes' has no attribute '_shared_axes'
# ]
# [autoreload of matplotlib.figure failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/_docstring.py", line 57, in __missing__
#     cls, = [cls for cls in _api.recursive_subclasses(Artist)
# ValueError: not enough values to unpack (expected 1, got 0)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/figure.py", line 158, in <module>
#     class FigureBase(Artist):
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/figure.py", line 507, in FigureBase
#     def add_axes(self, *args, **kwargs):
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/_docstring.py", line 80, in __call__
#     super().__call__(obj)
# KeyError: 'Axes:kwdoc'
# ]
# [autoreload of matplotlib.backends.backend_agg failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of matplotlib.pyplot failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.8/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 848, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py", line 60, in <module>
#     from matplotlib.figure import Figure, FigureBase, figaspect
# ImportError: cannot import name 'FigureBase' from 'matplotlib.figure' (/usr/local/lib/python3.8/dist-packages/matplotlib/figure.py)
# ]
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting leidenalg
#   Downloading leidenalg-0.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.6 MB/s eta 0:00:00
# Collecting igraph<0.11,>=0.10.0
#   Downloading igraph-0.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 105.2 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.4 leidenalg-0.9.1 texttable-1.6.7

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1VHZIPFmOd_-Z3PGgavB9LVwCskoD0_-v/graphsc_dir/graphsc

# %%
import sys
sys.path.append("..")
import argparse
import numpy as np
import dgl
from dgl import DGLGraph
import torch
import torch.nn.functional as F
import time
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from collections import Counter
from sklearn.manifold import TSNE
import pickle
import h5py
import random
import glob2
import seaborn as sns

import train
import models

# %load_ext autoreload
# %autoreload 2

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
device = train.get_device()

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
path= "R/results/"
# check available files
# !ls ../real_data
# Out:
# ls: cannot access '../real_data': No such file or directory

# %%
# select dataset to analyze
dataset = 'Quake_Smart-seq2_Trachea'

# %%
data_mat = h5py.File(f"{path}real_data/{dataset}.h5", "r")
X = np.array(data_mat['X'])
Y = np.array(data_mat['Y'])
print("Sparsity: ", np.where(X ==0)[0].shape[0]/(X.shape[0]*X.shape[1]))
normalize_weights = "log_per_cell"

n_layers = 1
hidden_dim = 200
hidden = [300]
nb_genes = 3000
activation = F.relu
epochs = 10
batch_size = 128 
pca_size = 50
# Out:
# Sparsity:  0.854844741489701

# %%
# remove less variable genes
genes_idx, cells_idx = train.filter_data(X, highly_genes=nb_genes)
X = X[cells_idx][:, genes_idx]
Y = Y[cells_idx]
n_clusters = len(np.unique(Y))

# create graph
graph = train.make_graph(
    X,
    Y, # Pass None of Y is not available for validation
    dense_dim=pca_size,
    normalize_weights=normalize_weights,
)
labels = graph.ndata["label"]
train_ids = np.where(labels != -1)[0]

# create training data loader
sampler = dgl.dataloading.MultiLayerFullNeighborSampler(n_layers)
dataloader = dgl.dataloading.NodeDataLoader(
    graph,
    train_ids,
    sampler,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
    num_workers=1,
)

# create model
model = models.GCNAE(
    in_feats=pca_size,
    n_hidden=hidden_dim,
    n_layers=n_layers,
    activation=activation,
    dropout=0.1,
    hidden=hidden,
).to(device)

optim = torch.optim.Adam(model.parameters(), lr=1e-5)
# train model
results = train.train(model,
                     optim,
                     epochs,
                     dataloader,
                     n_clusters,
                     plot=False,
                     save = True,
                     cluster=["KMeans", "Leiden"])
# Out:
# /usr/local/lib/python3.8/dist-packages/dgl/heterograph.py:72: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   dgl_warning('Recommend creating graphs by `dgl.graph(data)`'
#   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/dgl/dataloading/dataloader.py:859: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(f'Dataloader CPU affinity opt is not enabled, consider switching it on '
# ARI 0.8485, 0.46110737323760986

# %%
results.keys()
# Out:
# dict_keys(['ae_end', 'features', 'y', 'kmeans_ari', 'kmeans_nmi', 'kmeans_sil', 'kmeans_cal', 'kmeans_pred', 'kmeans_time', 'leiden_ari', 'leiden_nmi', 'leiden_sil', 'leiden_cal', 'leiden_pred', 'leiden_time', 'aris_kmeans'])

# %% [markdown]
# # Visualize results

# %%
X_embedded = TSNE(n_components=2).fit_transform(results["features"])

# %%
plt.scatter(X_embedded[:,0],X_embedded[:,1], c = results['kmeans_pred'])
plt.title(f"Kmeans clustering ARI:{results['kmeans_ari']}\n"+
          f"Sil:{round(float(results['kmeans_sil']),2)}, NMI:{results['kmeans_nmi']}, "+
          f"Calinski:{round(float(results['kmeans_cal']),2)}"
         );

# %%
plt.scatter(X_embedded[:,0],X_embedded[:,1], c = results['leiden_pred'])
plt.title(f"Leiden clustering ARI:{results['leiden_ari']}\n"+
          f"Sil:{round(float(results['leiden_sil']),2)}, NMI:{results['leiden_nmi']}, "+
          f"Calinski:{round(float(results['leiden_cal']),2)}"
         );
